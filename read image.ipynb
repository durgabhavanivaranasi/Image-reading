# %%
import cv2
import matplotlib.pyplot as plt

# %%
path=r"C:\Users\DURGA BHAVANI\Desktop\notesdetection\5Hundrednote\2.jpg"
img=cv2.imread(path)

# %%
print(img)
# Out:
# [[[166  61  12]
#   [166  61  12]
#   [166  61  12]
#   ...
#   [ 36  58  94]
#   [ 40  61  99]
#   [ 40  63 101]]
#
#  [[166  61  12]
#   [166  61  12]
#   [166  61  12]
#   ...
#   [ 36  58  94]
#   [ 40  61  99]
#   [ 40  63 101]]
#
#  [[168  60  12]
#   [168  60  12]
#   [168  60  12]
#   ...
#   [ 36  58  94]
#   [ 40  61  99]
#   [ 40  63 101]]
#
#  ...
#
#  [[ 44  70 106]
#   [ 43  69 105]
#   [ 44  70 106]
#   ...
#   [117 148 203]
#   [115 144 201]
#   [113 142 199]]
#
#  [[ 45  71 107]
#   [ 41  67 103]
#   [ 40  66 102]
#   ...
#   [122 154 207]
#   [120 150 205]
#   [118 147 204]]
#
#  [[ 46  72 108]
#   [ 39  65 101]
#   [ 37  63  99]
#   ...
#   [130 162 215]
#   [128 158 213]
#   [128 155 211]]]

# %%
plt.imshow(img)

# %%
import cv2

# %%
img=cv2.imread(r"C:\Users\DURGA BHAVANI\Desktop\notesdetection\5Hundrednote\2.jpg")

# %%
cv2.imshow("image",img)
